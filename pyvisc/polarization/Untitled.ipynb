# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import mplhep as hep
hep.set_style("ATLAS")

# %%
N=1000
#dat = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test//20_50/event0/polar_shear_lrf.dat")
#for i in range(1,N):
#    dat1 = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test//20_50/event%s/polar_shear_lrf.dat"%i)
#    dat = dat +  dat1

#dat = dat/(N*1.0)
#plt.plot(dat[:,0],dat[:,4]*100,label="shear")


dat = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test//20_50/event0/polar_th.dat")
for i in range(1,N):
    dat1 = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test//20_50/event%s/polar_th.dat"%i)
    dat = dat +  dat1

dat = dat/(N*1.0)
plt.plot(dat[:,0],dat[:,4]*100,label="th")
plt.plot(dat[:,0],dat[:,4]*0)
plt.plot(dat[:,0]/dat[:,0]*np.pi/2,dat[:,4]*100)

dat = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test//20_50/event0/polar_th_lrf.dat")
for i in range(1,N):
   dat1 = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test//20_50/event%s/polar_th_lrf.dat"%i)
   dat = dat +  dat1

dat = dat/(N*1.0)
#plt.plot(dat[:,0],dat[:,4]*100,label="accT")
plt.xlim(0.0,np.pi)
plt.ylim(-1.5,1.5)
plt.xlabel(r"$\phi_p$",loc="center")
plt.ylabel(r"$P^Z \times 10^2$",loc="center")
plt.legend()
# Out:
# /home/xywu/anaconda2/envs/pytorch/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in true_divide

# %%
N=800
dat = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test//20_50/event0/polar_shear_lrf.dat")
for i in range(1,N):
    dat1 = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test//20_50/event%s/polar_shear_lrf.dat"%i)
    dat = dat +  dat1

dat = dat/(N*1.0)
plt.plot(dat[:,0],-dat[:,3]*1000,label="shear")


dat2 = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test//20_50/event0/polar_th_lrf.dat")
for i in range(1,N):
    dat1 = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test//20_50/event%s/polar_th_lrf.dat"%i)
    dat2 = dat2 +  dat1

dat2 = dat2/(N*1.0)
plt.plot(dat2[:,0],-dat2[:,3]*1000,label="th")

dat3 = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test//20_50/event0/polar_accT_lrf.dat")
for i in range(1,N):
    dat1 = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test//20_50/event%s/polar_accT_lrf.dat"%i)
    dat3 = dat3 +  dat1

dat3 = dat3/(N*1.0)
plt.plot(dat3[:,0],-dat3[:,3]*1000,label="accT")
plt.plot(dat3[:,0],-(dat3[:,3]+dat[:,3]+dat2[:,3])*1000,label="accT")
plt.xlim(0.0,np.pi)
plt.ylim(-3,3)
plt.xlabel(r"$\phi_p$",loc="center")
plt.ylabel(r"$P^Z \times 10^3$",loc="center")
plt.legend()

# %%
N=10
dat = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test/20_50/event0/polar_th_lrf.dat")
for i in range(1,N):
    dat1 = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo_test/20_50/event%s/polar_th_lrf.dat"%i)
    dat = dat +  dat1

dat = dat/(N*1.0)
plt.plot(dat[:,0],dat[:,4]*100,label="shear1")



dat = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo/20_50/event0/polar1.dat")
for i in range(1,N):
    dat1 = np.loadtxt("../results/auau200_results_ampt/etas0p08_kfactor1p4_wo/20_50/event%s/polar1.dat"%i)
    dat = dat +  dat1

dat = dat/(N*1.0)
plt.plot(dat[:,0],dat[:,4]*100,label="shear")

plt.xlim(0.0,np.pi)
plt.legend()
